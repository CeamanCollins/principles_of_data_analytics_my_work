# %%
import pandas as pd

# %%
import_export_data_23 = pd.read_csv('HDF_calckWh_10000847339_26-02-2025.csv')

# %%
import_export_data_23
# Out:
#               MPRN  Meter Serial Number  Read Value  \
# 0      10000847339             34153614      0.0045
# 1      10000847339             34153614      0.2050
# 2      10000847339             34153614      0.0245
# 3      10000847339             34153614      0.0000
# 4      10000847339             34153614      0.0000
# ...            ...                  ...         ...
# 42693  10000847339             34153614      0.0300
# 42694  10000847339             34153614      0.0295
# 42695  10000847339             34153614      0.0655
# 42696  10000847339             34153614      0.0665
# 42697  10000847339             34153614      0.0295
#
#                           Read Type Read Date and End Time
# 0      Active Export Interval (kWh)       25-02-2025 00:00
# 1      Active Import Interval (kWh)       25-02-2025 00:00
# 2      Active Import Interval (kWh)       24-02-2025 23:30
# 3      Active Export Interval (kWh)       24-02-2025 23:30
# ...

# %%
import_export_data_23[import_export_data_23['Read Type'] == 'Active Import Interval (kWh)'].loc[:,['Read Value','Read Date and End Time']][import_export_data_23['Read Date and End Time'] =='24-01-2024 00:30']
# Out:
# /var/folders/rg/v4nzhwmx4qx4m3qz6yr0s8700000gn/T/ipykernel_10391/1467547406.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import_export_data_23[import_export_data_23['Read Type'] == 'Active Import Interval (kWh)'].loc[:,['Read Value','Read Date and End Time']][import_export_data_23['Read Date and End Time'] =='24-01-2024 00:30']
#        Read Value Read Date and End Time
# 38103       0.116       24-01-2024 00:30
